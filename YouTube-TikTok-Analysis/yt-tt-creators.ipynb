# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\LINGESH A\OneDrive\Desktop\py\top_creators_impact_2025.csv")
df
# Out:
#      author_handle platform  n_videos     views    avg_er  likes_sum  \
# 0      UrbanVision   TikTok       136  17938952  0.091914    1267238
# 1     BeyondStudio   TikTok       135  17085072  0.087916    1121223
# 2     StreetVision   TikTok       133  16843324  0.093018    1228515
# 3        NextMedia   TikTok       148  16325236  0.092222    1161803
# 4        PrimeLabs   TikTok       135  16240032  0.092307    1095828
# ..             ...      ...       ...       ...       ...        ...
# 995       GuruYuki  YouTube        21   1865526  0.050216      80938
# 996  OfficialSofia   TikTok        18   1858897  0.090631     126563
# 997   TravelByNoor  YouTube        18   1857824  0.056072      69365
# 998        TVDiego  YouTube        20   1856301  0.055188      71928
# 999    BeautyByAmr   TikTok        21   1854548  0.092891     117331
#
#      dislikes_sum  comments_sum  shares_sum  saves_sum  total_engagements  \
# ...

# %%
df.shape
# Out:
# (1000, 20)

# %%
tt_top=df.sort_values(by="views",ascending=False)
tt_top.loc[tt_top["platform"]=="TikTok",["author_handle","views"]].head(10)
# Out:
#   author_handle     views
# 0   UrbanVision  17938952
# 1  BeyondStudio  17085072
# 2  StreetVision  16843324
# 3     NextMedia  16325236
# 4     PrimeLabs  16240032
# 5    NextVision  15358183
# 6     BeyondHub  14998702
# 7     VividLabs  14825789
# 8    VividWorks  14056602
# 9  InsideVision  13895416

# %% [markdown]
# #### This shows top 10 creators in TikTok with most views

# %%
tt_top.loc[tt_top["platform"]=="YouTube",["author_handle","views"]].head(10)
# Out:
#    author_handle     views
# 19    VividWorks  13100235
# 21    PrimeMedia  12796075
# 43     VividLabs  10197573
# 44   BeyondWorks  10050064
# 47    NextStudio   9790132
# 49       NextHub   9762487
# 52  BeyondStudio   9635708
# 53  StreetStudio   9609984
# 54     BeyondHub   9549059
# 57     UrbanLabs   9454222

# %% [markdown]
# #### This shows top 10 creators in YouTube(only shorts) with most views
